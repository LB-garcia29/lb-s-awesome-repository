# %%
row=int(input("Enter amount of rows. "))

i=0
print("<table>")
while i<row:
    if i%2==0:
        i+=1
        print("<tr class='lightyellowrow'><td>",i,"</td><td>",i*i,"</td></tr>")
    else:
        i+=1
        print("<tr class='whiterow'><td>",i,"</td><td>",i*i,"</td></tr>")
print("<table>")
# Out:
# Enter amount of rows. 5
# <table>
# <tr class='lightyellowrow'><td> 1 </td><td> 1 </td></tr>
# <tr class='whiterow'><td> 2 </td><td> 4 </td></tr>
# <tr class='lightyellowrow'><td> 3 </td><td> 9 </td></tr>
# <tr class='whiterow'><td> 4 </td><td> 16 </td></tr>
# <tr class='lightyellowrow'><td> 5 </td><td> 25 </td></tr>
# <table>

# %%
day=int(input("Day: "))
month=int(input("Month: "))
year=int(input("Year: "))
valid=1
if year<0:
    print("Year is Invalid")
    valid=0
if month==1:
    string_month="January"
elif month==2:
    string_month="February"
elif month==3:
    string_month="March"
elif month==4:
    string_month="April"
elif month==5:
    string_month="May"
elif month==6:
    string_month="June"
elif month==7:
    string_month="July"
elif month==8:
    string_month="August"
elif month==9:
    string_month="September"
elif month==10:
    string_month="October"
elif month==11:
    string_month="November"
elif month==12:
    string_month="December"
else:
    print("Month is not valid!")
    valid=0
if year%4==0 or year%100==0 and year%400:
    if month==1 or month==3 or month==5 or month==7 or month==8 or month==10 or month==12:
        if day<=31and day>0:
            if day==1 or day==21 or day==31:
                suffix="st"
            elif day==2 or day==22:
                suffix="nd"
            elif day==3 or day==23:
                suffix="rd"
            else:
                suffix="th"
        else:
            print("Date is not valid!")
            valid=0
    else:
        if month==2:
            if day<=29 and day>0:
                if day==1 or day==21:
                    suffix="st"
                elif day==2 or day==22:
                    suffix="nd"
                elif day==3 or day==23:
                    suffix="rd"
                else:
                    suffix="th"
            else:
                print("Date is not valid!")
                valid=0
        elif month==4 or month==6 or month==9 or month==11:
            
            if day<=30and day>0:
                if day==1 or day==21:
                    suffix="st"
                elif day==2 or day==22:
                    suffix="nd"
                elif day==3 or day==23:
                    suffix="rd"
                else:
                    suffix="th"
            else:
                print("Date is not valid!")
                valid=0
else:
    if month==1 or month==3 or month==5 or month==7 or month==8 or month==10 or month==12:
        if day<=31and day>0:
            if day==1 or day==21 or day==31:
                suffix="st"
            elif day==2 or day==22:
                suffix="nd"
            elif day==3 or day==23:
                suffix="rd"
            else:
                suffix="th"
        else:
            print("Date is not valid!")
            valid=0
    else:
        if month==2:
            if day<=28 and day>0:
                if day==1 or day==21:
                    suffix="st"
                elif day==2 or day==22:
                    suffix="nd"
                elif day==3 or day==23:
                    suffix="rd"
                else:
                    suffix="th"
            else:
                print("Date is not valid!")
                valid=0
        elif month==4 or month==6 or month==9 or month==11:
            
            if day<=30and day>0:
                if day==1 or day==21:
                    suffix="st"
                elif day==2 or day==22:
                    suffix="nd"
                elif day==3 or day==23:
                    suffix="rd"
                else:
                    suffix="th"
            else:
                print("Date is not valid!")
                valid=0
if valid==1:
    print("it is the {}{} day of the month of {} of the year {}" .format(day,suffix,string_month,year))
# Out:
# Day: 1
# Month: 1
# Year: -1
# Year is Invalid
# it is the 1st day of the month of January of the year -1

# %%
def obedient(x):
    if x>3:
        if x%3==0:
            return(True)
        else:
            return(False)
    else:
        return(False)

# %%
print(obedient(5))
# Out:
# False

# %%
def multtable(x):
    i=1
    while i<x+1:
        o=1
        while o<x+1:
            print(i*o,end="\t") 
            o+=1
        i+=1
        print()

# %%
multtable(5)
# Out:
# 1	2	3	4	5
# 2	4	6	8	10
# 3	6	9	12	15
# 4	8	12	16	20
# 5	10	15	20	25

# %%
#Do you prefer (a) the mountains, (b) the city, or (c) the beach?
#Do you prefer (a) yoghurt, (b) ice cream, or (c) gelato?
#Do you prefer (a) reading, (b) singing, or (c) writing?
#Do you prefer (a) sweet, (b) salty, or (c) spicy food?
#Do you prefer (a) cats, (b) dogs, or (c) fish?
#Q1: mountains = fire, city = earth, beach = water
#Q2: yoghurt = earth, ice cream = water, gelato = fire
#Q3: reading = water, singing = fire, writing = earth
#Q4: sweet = earth, salty = water, spicy = fire
#Q5: cats = earth, dogs = fire, fish = water
i=0
while i<5:
    fire=0 
    water=0 
    earth=0
    q1=input("Do you prefer (a) the mountains, (b) the city, or (c) the beach? ")
    if q1=="a":
        fire+=1
        i+=1
    elif q1=="b":
        earth+=1
        i+=1
    elif q1=="c":
        earth+=1
        i+=1
    else:
        print("“Sorry, you inputted a wrong letter. Please start again.")
        i=0
        continue
    q2=input("Do you prefer (a) yoghurt, (b) ice cream, or (c) gelato? ")
        
    if q2=="a":
        earth+=1
        i+=1
    elif q2=="b":
        water+=1
        i+=1
    elif q2=="c":
        fire+=1
        i+=1
    else:
        print("“Sorry, you inputted a wrong letter. Please start again.")
        i=0
        continue
     
    q3=input("Do you prefer (a) reading, (b) singing, or (c) writing? ")
    if q3=="a":
        water+=1
        i+=1
    elif q3=="b":
        fire+=1
        i+=1
    elif q3=="c":
        earth+=1
        i+=1
    else:
        print("“Sorry, you inputted a wrong letter. Please start again.")
        i=0
        continue
            
    q4=input("Do you prefer (a) sweet, (b) salty, or (c) spicy food? ")
    if q4=="a":
        earth+=1
        i+=1
    elif q4=="b":
        water+=1
        i+=1
    elif q4=="c":
        fire+=1
        i+=1
    else:
        print("“Sorry, you inputted a wrong letter. Please start again.")
        i=0
        continue
            
    q5=input("Do you prefer (a) cats, (b) dogs, or (c) fish? ")
    if q5=="a":
        earth+=1
        i+=1
    elif q5=="b":
        fire+=1
        i+=1
    elif q5=="c":
        water+=1
        i+=1
    else:
        print("“Sorry, you inputted a wrong letter. Please start again.")
        i=0
        continue
            
        
if fire==earth:
    print("Your element is Earth!")
    
elif water==earth:
    print("Your element is Water!")
    
elif fire==water:
    print("Your element is Fire!")
    
elif fire>water:
    if fire>earth:
        print("Your element is Fire!")
    else:
        print("Your element is Earth")
elif water>fire:
    if water>earth:
         print("Your element is Water!")
    else:
        print("Your element is Earth!")
elif earth>water:
    if earth>fire:
        print("Your element is Earth!")
    else:
        print("Your element is Fire!")
elif water>earth:
    if water>fire:
         print("Your element is Water!")
    else:
        print("Your element is Fire!")
elif earth>fire:
    if earth>water:
         print("Your element is Earth!")
    else:
         print("Your element is Water!")
elif fire>earth:
    if fire>water:
        print("Your element is Fire!")
    else:
        print("Your element is Water!")
# Out:
# Do you prefer (a) the mountains, (b) the city, or (c) the beach? a
# Do you prefer (a) yoghurt, (b) ice cream, or (c) gelato? sex
# “Sorry, you inputted a wrong letter. Please start again.
# Do you prefer (a) the mountains, (b) the city, or (c) the beach? a
# Do you prefer (a) yoghurt, (b) ice cream, or (c) gelato? b
# Do you prefer (a) reading, (b) singing, or (c) writing? penis
# “Sorry, you inputted a wrong letter. Please start again.
